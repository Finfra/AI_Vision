# %%
# fork 생략
# !git clone https://github.com/anishathalye/neural-style.git
# %cd neural-style

# %%
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# !ls *.mat

# %%
# !pip uninstall -y scipy
# !pip install scipy==1.1.0

# %%
import scipy as sc
print(sc.__version__)
# TensorFlow
import tensorflow as tf
print(tf.__version__)
# NumPy
import numpy as np
print(np.__version__)
# SciPy
import scipy as sc
print(sc.__version__)
# Pillow
import PIL
print(PIL.__version__)

# %%
# %cd /content/neural-style

# !python neural_style.py    \
  --content ./examples/1-content.jpg \
 --styles ./examples/2-style1.jpg     \
 --output ./o1.jpg
# Out:
# /content/neural-style
# WARNING: Logging before flag parsing goes to stderr.
# W0801 05:57:25.837472 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0801 05:57:25.837731 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-01 05:57:25.852769: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-08-01 05:57:25.853044: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x23ab2c0 executing computations on platform Host. Devices:
# 2019-08-01 05:57:25.853093: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-01 05:57:25.855081: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-08-01 05:57:26.027793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.028386: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x23abd40 executing computations on platform CUDA. Devices:
# 2019-08-01 05:57:26.028448: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-08-01 05:57:26.028714: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.029120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-01 05:57:26.029459: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:26.030724: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:26.031857: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-01 05:57:26.032194: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-01 05:57:26.033584: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-01 05:57:26.034669: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-01 05:57:26.037673: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-01 05:57:26.037792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.038191: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.038508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-01 05:57:26.038562: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:26.039358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-01 05:57:26.039386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-01 05:57:26.039394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-01 05:57:26.039664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.040054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:26.040404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2019-08-01 05:57:30.156541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.157050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-01 05:57:30.157114: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:30.157138: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:30.157167: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-01 05:57:30.157185: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-01 05:57:30.157206: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-01 05:57:30.157224: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-01 05:57:30.157242: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-01 05:57:30.157320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.157740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.158089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-01 05:57:30.158716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.159077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-01 05:57:30.159121: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:30.159141: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:30.159158: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-01 05:57:30.159178: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-01 05:57:30.159195: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-01 05:57:30.159212: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-01 05:57:30.159229: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-01 05:57:30.159304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.159687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.159999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-01 05:57:30.160050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-01 05:57:30.160082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-01 05:57:30.160092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-01 05:57:30.160365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.160743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:30.161086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0801 05:57:30.161304 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/stylize.py:73: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0801 05:57:30.187062 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/vgg.py:78: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2019-08-01 05:57:30.720611: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# 2019-08-01 05:57:35.109147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:35.109555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-01 05:57:35.109621: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:35.109644: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:35.109664: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-01 05:57:35.109684: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-01 05:57:35.109703: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-01 05:57:35.109722: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-01 05:57:35.109742: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-01 05:57:35.109839: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:35.110306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:35.110630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-01 05:57:35.110670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-01 05:57:35.110683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-01 05:57:35.110695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-01 05:57:35.110956: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:35.111350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:35.111680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0801 05:57:40.431726 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/stylize.py:98: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0801 05:57:40.910188 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/stylize.py:165: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# 2019-08-01 05:57:41.299318: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:41.299782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2019-08-01 05:57:41.299847: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-08-01 05:57:41.299873: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:41.299894: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-08-01 05:57:41.299917: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-08-01 05:57:41.299942: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-08-01 05:57:41.299962: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-08-01 05:57:41.299982: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-08-01 05:57:41.300107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:41.300576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:41.300939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-08-01 05:57:41.300976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-08-01 05:57:41.300989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-08-01 05:57:41.300999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-08-01 05:57:41.301309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:41.301735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-08-01 05:57:41.302127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14202 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0801 05:57:41.302356 140514097850240 deprecation_wrapper.py:119] From /content/neural-style/stylize.py:171: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Optimization started...
# Iteration    1/1000
# 2019-08-01 05:57:43.888928: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-08-01 05:57:44.530349: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# Iteration    2/1000 (6 sec elapsed, 1 hr 52 min remaining)
# Iteration    3/1000 (6 sec elapsed, 56 min 48 sec remaining)
# Iteration    4/1000 (6 sec elapsed, 38 min 18 sec remaining)
# Iteration    5/1000 (7 sec elapsed, 29 min 4 sec remaining)
# Iteration    6/1000 (7 sec elapsed, 23 min 31 sec remaining)
# Iteration    7/1000 (7 sec elapsed, 19 min 49 sec remaining)
# Iteration    8/1000 (7 sec elapsed, 17 min 10 sec remaining)
# Iteration    9/1000 (7 sec elapsed, 15 min 11 sec remaining)
# Iteration   10/1000 (7 sec elapsed, 13 min 39 sec remaining)
# Iteration   11/1000 (7 sec elapsed, 12 min 25 sec remaining)
# Iteration   12/1000 (7 sec elapsed, 1 min 26 sec remaining)
# Iteration   13/1000 (7 sec elapsed, 1 min 26 sec remaining)
# Iteration   14/1000 (7 sec elapsed, 1 min 26 sec remaining)
# Iteration   15/1000 (7 sec elapsed, 1 min 25 sec remaining)
# Iteration   16/1000 (7 sec elapsed, 1 min 25 sec remaining)
# Iteration   17/1000 (8 sec elapsed, 1 min 25 sec remaining)
# Iteration   18/1000 (8 sec elapsed, 1 min 25 sec remaining)
# Iteration   19/1000 (8 sec elapsed, 1 min 25 sec remaining)
# Iteration   20/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   21/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   22/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   23/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   24/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   25/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   26/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   27/1000 (8 sec elapsed, 1 min 24 sec remaining)
# Iteration   28/1000 (9 sec elapsed, 1 min 24 sec remaining)
# Iteration   29/1000 (9 sec elapsed, 1 min 24 sec remaining)
# Iteration   30/1000 (9 sec elapsed, 1 min 24 sec remaining)
# Iteration   31/1000 (9 sec elapsed, 1 min 24 sec remaining)
# Iteration   32/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   33/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   34/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   35/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   36/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   37/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   38/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   39/1000 (9 sec elapsed, 1 min 23 sec remaining)
# Iteration   40/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   41/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   42/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   43/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   44/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   45/1000 (10 sec elapsed, 1 min 22 sec remaining)
# Iteration   46/1000 (10 sec elapsed, 1 min 22 sec remaining)
# Iteration   47/1000 (10 sec elapsed, 1 min 22 sec remaining)
# Iteration   48/1000 (10 sec elapsed, 1 min 23 sec remaining)
# Iteration   49/1000 (10 sec elapsed, 1 min 22 sec remaining)
# Iteration   50/1000 (10 sec elapsed, 1 min 22 sec remaining)
# Iteration   51/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   52/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   53/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   54/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   55/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   56/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   57/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   58/1000 (11 sec elapsed, 1 min 22 sec remaining)
# Iteration   59/1000 (11 sec elapsed, 1 min 21 sec remaining)
# Iteration   60/1000 (11 sec elapsed, 1 min 21 sec remaining)
# Iteration   61/1000 (11 sec elapsed, 1 min 21 sec remaining)
# Iteration   62/1000 (11 sec elapsed, 1 min 21 sec remaining)
# Iteration   63/1000 (12 sec elapsed, 1 min 21 sec remaining)
# Iteration   64/1000 (12 sec elapsed, 1 min 21 sec remaining)
# Iteration   65/1000 (12 sec elapsed, 1 min 21 sec remaining)
# Iteration   66/1000 (12 sec elapsed, 1 min 21 sec remaining)
# Iteration   67/1000 (12 sec elapsed, 1 min 21 sec remaining)
# Iteration   68/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   69/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   70/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   71/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   72/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   73/1000 (12 sec elapsed, 1 min 20 sec remaining)
# Iteration   74/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   75/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   76/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   77/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   78/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   79/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   80/1000 (13 sec elapsed, 1 min 20 sec remaining)
# Iteration   81/1000 (13 sec elapsed, 1 min 19 sec remaining)
# Iteration   82/1000 (13 sec elapsed, 1 min 19 sec remaining)
# Iteration   83/1000 (13 sec elapsed, 1 min 19 sec remaining)
# Iteration   84/1000 (13 sec elapsed, 1 min 19 sec remaining)
# Iteration   85/1000 (13 sec elapsed, 1 min 19 sec remaining)
# Iteration   86/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   87/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   88/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   89/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   90/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   91/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   92/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   93/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   94/1000 (14 sec elapsed, 1 min 19 sec remaining)
# Iteration   95/1000 (14 sec elapsed, 1 min 18 sec remaining)
# Iteration   96/1000 (14 sec elapsed, 1 min 18 sec remaining)
# Iteration   97/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration   98/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration   99/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  100/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  101/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  102/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  103/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  104/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  105/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  106/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  107/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  108/1000 (15 sec elapsed, 1 min 18 sec remaining)
# Iteration  109/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  110/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  111/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  112/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  113/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  114/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  115/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  116/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  117/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  118/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  119/1000 (16 sec elapsed, 1 min 17 sec remaining)
# Iteration  120/1000 (17 sec elapsed, 1 min 17 sec remaining)
# Iteration  121/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  122/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  123/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  124/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  125/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  126/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  127/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  128/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  129/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  130/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  131/1000 (17 sec elapsed, 1 min 16 sec remaining)
# Iteration  132/1000 (18 sec elapsed, 1 min 16 sec remaining)
# Iteration  133/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  134/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  135/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  136/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  137/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  138/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  139/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  140/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  141/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  142/1000 (18 sec elapsed, 1 min 15 sec remaining)
# Iteration  143/1000 (19 sec elapsed, 1 min 15 sec remaining)
# Iteration  144/1000 (19 sec elapsed, 1 min 15 sec remaining)
# Iteration  145/1000 (19 sec elapsed, 1 min 15 sec remaining)
# Iteration  146/1000 (19 sec elapsed, 1 min 15 sec remaining)
# Iteration  147/1000 (19 sec elapsed, 1 min 15 sec remaining)
# Iteration  148/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  149/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  150/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  151/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  152/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  153/1000 (19 sec elapsed, 1 min 14 sec remaining)
# Iteration  154/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  155/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  156/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  157/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  158/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  159/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  160/1000 (20 sec elapsed, 1 min 14 sec remaining)
# Iteration  161/1000 (20 sec elapsed, 1 min 13 sec remaining)
# Iteration  162/1000 (20 sec elapsed, 1 min 13 sec remaining)
# Iteration  163/1000 (20 sec elapsed, 1 min 13 sec remaining)
# Iteration  164/1000 (20 sec elapsed, 1 min 13 sec remaining)
# Iteration  165/1000 (20 sec elapsed, 1 min 13 sec remaining)
# Iteration  166/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  167/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  168/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  169/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  170/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  171/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  172/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  173/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  174/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  175/1000 (21 sec elapsed, 1 min 13 sec remaining)
# Iteration  176/1000 (21 sec elapsed, 1 min 12 sec remaining)
# Iteration  177/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  178/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  179/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  180/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  181/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  182/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  183/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  184/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  185/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  186/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  187/1000 (22 sec elapsed, 1 min 12 sec remaining)
# Iteration  188/1000 (23 sec elapsed, 1 min 12 sec remaining)
# Iteration  189/1000 (23 sec elapsed, 1 min 12 sec remaining)
# Iteration  190/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  191/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  192/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  193/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  194/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  195/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  196/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  197/1000 (23 sec elapsed, 1 min 10 sec remaining)
# Iteration  198/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  199/1000 (23 sec elapsed, 1 min 11 sec remaining)
# Iteration  200/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  201/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  202/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  203/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  204/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  205/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  206/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  207/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  208/1000 (24 sec elapsed, 1 min 10 sec remaining)
# Iteration  209/1000 (24 sec elapsed, 1 min 9 sec remaining)
# Iteration  210/1000 (24 sec elapsed, 1 min 9 sec remaining)
# Iteration  211/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  212/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  213/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  214/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  215/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  216/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  217/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  218/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  219/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  220/1000 (25 sec elapsed, 1 min 9 sec remaining)
# Iteration  221/1000 (25 sec elapsed, 1 min 8 sec remaining)
# Iteration  222/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  223/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  224/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  225/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  226/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  227/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  228/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  229/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  230/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  231/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  232/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  233/1000 (26 sec elapsed, 1 min 8 sec remaining)
# Iteration  234/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  235/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  236/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  237/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  238/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  239/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  240/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  241/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  242/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  243/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  244/1000 (27 sec elapsed, 1 min 7 sec remaining)
# Iteration  245/1000 (28 sec elapsed, 1 min 7 sec remaining)
# Iteration  246/1000 (28 sec elapsed, 1 min 7 sec remaining)
# Iteration  247/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  248/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  249/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  250/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  251/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  252/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  253/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  254/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  255/1000 (28 sec elapsed, 1 min 6 sec remaining)
# Iteration  256/1000 (29 sec elapsed, 1 min 6 sec remaining)
# Iteration  257/1000 (29 sec elapsed, 1 min 6 sec remaining)
# Iteration  258/1000 (29 sec elapsed, 1 min 6 sec remaining)
# Iteration  259/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  260/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  261/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  262/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  263/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  264/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  265/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  266/1000 (29 sec elapsed, 1 min 5 sec remaining)
# Iteration  267/1000 (30 sec elapsed, 1 min 5 sec remaining)
# Iteration  268/1000 (30 sec elapsed, 1 min 5 sec remaining)
# Iteration  269/1000 (30 sec elapsed, 1 min 5 sec remaining)
# Iteration  270/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  271/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  272/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  273/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  274/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  275/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  276/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  277/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  278/1000 (30 sec elapsed, 1 min 4 sec remaining)
# Iteration  279/1000 (31 sec elapsed, 1 min 4 sec remaining)
# Iteration  280/1000 (31 sec elapsed, 1 min 4 sec remaining)
# Iteration  281/1000 (31 sec elapsed, 1 min 4 sec remaining)
# Iteration  282/1000 (31 sec elapsed, 1 min 4 sec remaining)
# Iteration  283/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  284/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  285/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  286/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  287/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  288/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  289/1000 (31 sec elapsed, 1 min 3 sec remaining)
# Iteration  290/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  291/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  292/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  293/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  294/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  295/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  296/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  297/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  298/1000 (32 sec elapsed, 1 min 3 sec remaining)
# Iteration  299/1000 (32 sec elapsed, 1 min 2 sec remaining)
# Iteration  300/1000 (32 sec elapsed, 1 min 2 sec remaining)
# Iteration  301/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  302/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  303/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  304/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  305/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  306/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  307/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  308/1000 (33 sec elapsed, 1 min 2 sec remaining)
# Iteration  309/1000 (33 sec elapsed, 1 min 1 sec remaining)
# Iteration  310/1000 (33 sec elapsed, 1 min 1 sec remaining)
# Iteration  311/1000 (33 sec elapsed, 1 min 1 sec remaining)
# Iteration  312/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  313/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  314/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  315/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  316/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  317/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  318/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  319/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  320/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  321/1000 (34 sec elapsed, 1 min 1 sec remaining)
# Iteration  322/1000 (34 sec elapsed, 1 min 0 sec remaining)
# Iteration  323/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  324/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  325/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  326/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  327/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  328/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  329/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  330/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  331/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  332/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  333/1000 (35 sec elapsed, 1 min 0 sec remaining)
# Iteration  334/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  335/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  336/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  337/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  338/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  339/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  340/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  341/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  342/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  343/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  344/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  345/1000 (36 sec elapsed, 59 sec remaining)
# Iteration  346/1000 (37 sec elapsed, 59 sec remaining)
# Iteration  347/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  348/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  349/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  350/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  351/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  352/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  353/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  354/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  355/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  356/1000 (37 sec elapsed, 58 sec remaining)
# Iteration  357/1000 (38 sec elapsed, 58 sec remaining)
# Iteration  358/1000 (38 sec elapsed, 58 sec remaining)
# Iteration  359/1000 (38 sec elapsed, 58 sec remaining)
# Iteration  360/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  361/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  362/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  363/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  364/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  365/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  366/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  367/1000 (38 sec elapsed, 57 sec remaining)
# Iteration  368/1000 (39 sec elapsed, 57 sec remaining)
# Iteration  369/1000 (39 sec elapsed, 57 sec remaining)
# Iteration  370/1000 (39 sec elapsed, 57 sec remaining)
# Iteration  371/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  372/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  373/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  374/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  375/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  376/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  377/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  378/1000 (39 sec elapsed, 56 sec remaining)
# Iteration  379/1000 (40 sec elapsed, 56 sec remaining)
# Iteration  380/1000 (40 sec elapsed, 56 sec remaining)
# Iteration  381/1000 (40 sec elapsed, 56 sec remaining)
# Iteration  382/1000 (40 sec elapsed, 56 sec remaining)
# Iteration  383/1000 (40 sec elapsed, 56 sec remaining)
# Iteration  384/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  385/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  386/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  387/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  388/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  389/1000 (40 sec elapsed, 55 sec remaining)
# Iteration  390/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  391/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  392/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  393/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  394/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  395/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  396/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  397/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  398/1000 (41 sec elapsed, 55 sec remaining)
# Iteration  399/1000 (41 sec elapsed, 54 sec remaining)
# Iteration  400/1000 (41 sec elapsed, 54 sec remaining)
# Iteration  401/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  402/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  403/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  404/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  405/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  406/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  407/1000 (42 sec elapsed, 54 sec remaining)
# Iteration  408/1000 (42 sec elapsed, 53 sec remaining)
# Iteration  409/1000 (42 sec elapsed, 53 sec remaining)
# Iteration  410/1000 (42 sec elapsed, 53 sec remaining)
# Iteration  411/1000 (42 sec elapsed, 53 sec remaining)
# Iteration  412/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  413/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  414/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  415/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  416/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  417/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  418/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  419/1000 (43 sec elapsed, 53 sec remaining)
# Iteration  420/1000 (43 sec elapsed, 52 sec remaining)
# Iteration  421/1000 (43 sec elapsed, 52 sec remaining)
# Iteration  422/1000 (43 sec elapsed, 52 sec remaining)
# Iteration  423/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  424/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  425/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  426/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  427/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  428/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  429/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  430/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  431/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  432/1000 (44 sec elapsed, 52 sec remaining)
# Iteration  433/1000 (45 sec elapsed, 52 sec remaining)
# Iteration  434/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  435/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  436/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  437/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  438/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  439/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  440/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  441/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  442/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  443/1000 (45 sec elapsed, 51 sec remaining)
# Iteration  444/1000 (46 sec elapsed, 51 sec remaining)
# Iteration  445/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  446/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  447/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  448/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  449/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  450/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  451/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  452/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  453/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  454/1000 (46 sec elapsed, 50 sec remaining)
# Iteration  455/1000 (47 sec elapsed, 50 sec remaining)
# Iteration  456/1000 (47 sec elapsed, 50 sec remaining)
# Iteration  457/1000 (47 sec elapsed, 50 sec remaining)
# Iteration  458/1000 (47 sec elapsed, 50 sec remaining)
# Iteration  459/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  460/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  461/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  462/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  463/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  464/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  465/1000 (47 sec elapsed, 49 sec remaining)
# Iteration  466/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  467/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  468/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  469/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  470/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  471/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  472/1000 (48 sec elapsed, 49 sec remaining)
# Iteration  473/1000 (48 sec elapsed, 48 sec remaining)
# Iteration  474/1000 (48 sec elapsed, 48 sec remaining)
# Iteration  475/1000 (48 sec elapsed, 48 sec remaining)
# Iteration  476/1000 (48 sec elapsed, 48 sec remaining)
# Iteration  477/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  478/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  479/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  480/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  481/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  482/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  483/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  484/1000 (49 sec elapsed, 48 sec remaining)
# Iteration  485/1000 (49 sec elapsed, 47 sec remaining)
# Iteration  486/1000 (49 sec elapsed, 47 sec remaining)
# Iteration  487/1000 (49 sec elapsed, 47 sec remaining)
# Iteration  488/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  489/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  490/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  491/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  492/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  493/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  494/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  495/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  496/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  497/1000 (50 sec elapsed, 47 sec remaining)
# Iteration  498/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  499/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  500/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  501/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  502/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  503/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  504/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  505/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  506/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  507/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  508/1000 (51 sec elapsed, 46 sec remaining)
# Iteration  509/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  510/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  511/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  512/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  513/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  514/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  515/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  516/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  517/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  518/1000 (52 sec elapsed, 45 sec remaining)
# Iteration  519/1000 (52 sec elapsed, 45 sec remaining)
# ...
# Iteration  739/1000 (1 min 13 sec elapsed, 25 sec remaining)
# Iteration  740/1000 (1 min 13 sec elapsed, 25 sec remaining)
# Iteration  741/1000 (1 min 13 sec elapsed, 25 sec remaining)
# Iteration  742/1000 (1 min 14 sec elapsed, 25 sec remaining)
# Iteration  743/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  744/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  745/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  746/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  747/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  748/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  749/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  750/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  751/1000 (1 min 14 sec elapsed, 24 sec remaining)
# Iteration  752/1000 (1 min 15 sec elapsed, 24 sec remaining)
# Iteration  753/1000 (1 min 15 sec elapsed, 24 sec remaining)
# Iteration  754/1000 (1 min 15 sec elapsed, 24 sec remaining)
# Iteration  755/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  756/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  757/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  758/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  759/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  760/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  761/1000 (1 min 15 sec elapsed, 23 sec remaining)
# Iteration  762/1000 (1 min 16 sec elapsed, 23 sec remaining)
# Iteration  763/1000 (1 min 16 sec elapsed, 23 sec remaining)
# Iteration  764/1000 (1 min 16 sec elapsed, 23 sec remaining)
# Iteration  765/1000 (1 min 16 sec elapsed, 23 sec remaining)
# Iteration  766/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  767/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  768/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  769/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  770/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  771/1000 (1 min 16 sec elapsed, 22 sec remaining)
# Iteration  772/1000 (1 min 17 sec elapsed, 22 sec remaining)
# Iteration  773/1000 (1 min 17 sec elapsed, 22 sec remaining)
# Iteration  774/1000 (1 min 17 sec elapsed, 22 sec remaining)
# Iteration  775/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  776/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  777/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  778/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  779/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  780/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  781/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  782/1000 (1 min 17 sec elapsed, 21 sec remaining)
# Iteration  783/1000 (1 min 18 sec elapsed, 21 sec remaining)
# Iteration  784/1000 (1 min 18 sec elapsed, 21 sec remaining)
# Iteration  785/1000 (1 min 18 sec elapsed, 21 sec remaining)
# Iteration  786/1000 (1 min 18 sec elapsed, 21 sec remaining)
# Iteration  787/1000 (1 min 18 sec elapsed, 21 sec remaining)
# Iteration  788/1000 (1 min 18 sec elapsed, 20 sec remaining)
# Iteration  789/1000 (1 min 18 sec elapsed, 20 sec remaining)
# Iteration  790/1000 (1 min 18 sec elapsed, 20 sec remaining)
# Iteration  791/1000 (1 min 18 sec elapsed, 20 sec remaining)
# Iteration  792/1000 (1 min 18 sec elapsed, 20 sec remaining)
# Iteration  793/1000 (1 min 19 sec elapsed, 20 sec remaining)
# Iteration  794/1000 (1 min 19 sec elapsed, 20 sec remaining)
# Iteration  795/1000 (1 min 19 sec elapsed, 20 sec remaining)
# Iteration  796/1000 (1 min 19 sec elapsed, 20 sec remaining)
# Iteration  797/1000 (1 min 19 sec elapsed, 20 sec remaining)
# Iteration  798/1000 (1 min 19 sec elapsed, 19 sec remaining)
# Iteration  799/1000 (1 min 19 sec elapsed, 19 sec remaining)
# Iteration  800/1000 (1 min 19 sec elapsed, 19 sec remaining)
# Iteration  801/1000 (1 min 19 sec elapsed, 19 sec remaining)
# Iteration  802/1000 (1 min 19 sec elapsed, 19 sec remaining)
# Iteration  803/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  804/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  805/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  806/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  807/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  808/1000 (1 min 20 sec elapsed, 19 sec remaining)
# Iteration  809/1000 (1 min 20 sec elapsed, 18 sec remaining)
# Iteration  810/1000 (1 min 20 sec elapsed, 18 sec remaining)
# Iteration  811/1000 (1 min 20 sec elapsed, 18 sec remaining)
# Iteration  812/1000 (1 min 20 sec elapsed, 18 sec remaining)
# Iteration  813/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  814/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  815/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  816/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  817/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  818/1000 (1 min 21 sec elapsed, 18 sec remaining)
# Iteration  819/1000 (1 min 21 sec elapsed, 17 sec remaining)
# Iteration  820/1000 (1 min 21 sec elapsed, 17 sec remaining)
# Iteration  821/1000 (1 min 21 sec elapsed, 17 sec remaining)
# Iteration  822/1000 (1 min 21 sec elapsed, 17 sec remaining)
# Iteration  823/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  824/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  825/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  826/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  827/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  828/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  829/1000 (1 min 22 sec elapsed, 17 sec remaining)
# Iteration  830/1000 (1 min 22 sec elapsed, 16 sec remaining)
# Iteration  831/1000 (1 min 22 sec elapsed, 16 sec remaining)
# Iteration  832/1000 (1 min 22 sec elapsed, 16 sec remaining)
# Iteration  833/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  834/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  835/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  836/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  837/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  838/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  839/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  840/1000 (1 min 23 sec elapsed, 16 sec remaining)
# Iteration  841/1000 (1 min 23 sec elapsed, 15 sec remaining)
# Iteration  842/1000 (1 min 23 sec elapsed, 15 sec remaining)
# Iteration  843/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  844/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  845/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  846/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  847/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  848/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  849/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  850/1000 (1 min 24 sec elapsed, 15 sec remaining)
# Iteration  851/1000 (1 min 24 sec elapsed, 14 sec remaining)
# Iteration  852/1000 (1 min 24 sec elapsed, 14 sec remaining)
# Iteration  853/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  854/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  855/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  856/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  857/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  858/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  859/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  860/1000 (1 min 25 sec elapsed, 14 sec remaining)
# Iteration  861/1000 (1 min 25 sec elapsed, 13 sec remaining)
# Iteration  862/1000 (1 min 25 sec elapsed, 13 sec remaining)
# Iteration  863/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  864/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  865/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  866/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  867/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  868/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  869/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  870/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  871/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  872/1000 (1 min 26 sec elapsed, 13 sec remaining)
# Iteration  873/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  874/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  875/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  876/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  877/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  878/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  879/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  880/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  881/1000 (1 min 27 sec elapsed, 12 sec remaining)
# Iteration  882/1000 (1 min 27 sec elapsed, 11 sec remaining)
# Iteration  883/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  884/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  885/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  886/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  887/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  888/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  889/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  890/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  891/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  892/1000 (1 min 28 sec elapsed, 11 sec remaining)
# Iteration  893/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  894/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  895/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  896/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  897/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  898/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  899/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  900/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  901/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  902/1000 (1 min 29 sec elapsed, 10 sec remaining)
# Iteration  903/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  904/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  905/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  906/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  907/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  908/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  909/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  910/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  911/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  912/1000 (1 min 30 sec elapsed, 9 sec remaining)
# Iteration  913/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  914/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  915/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  916/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  917/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  918/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  919/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  920/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  921/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  922/1000 (1 min 31 sec elapsed, 8 sec remaining)
# Iteration  923/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  924/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  925/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  926/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  927/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  928/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  929/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  930/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  931/1000 (1 min 32 sec elapsed, 7 sec remaining)
# Iteration  932/1000 (1 min 33 sec elapsed, 7 sec remaining)
# Iteration  933/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  934/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  935/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  936/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  937/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  938/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  939/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  940/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  941/1000 (1 min 33 sec elapsed, 6 sec remaining)
# Iteration  942/1000 (1 min 34 sec elapsed, 6 sec remaining)
# Iteration  943/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  944/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  945/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  946/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  947/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  948/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  949/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  950/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  951/1000 (1 min 34 sec elapsed, 5 sec remaining)
# Iteration  952/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  953/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  954/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  955/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  956/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  957/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  958/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  959/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  960/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  961/1000 (1 min 35 sec elapsed, 4 sec remaining)
# Iteration  962/1000 (1 min 36 sec elapsed, 4 sec remaining)
# Iteration  963/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  964/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  965/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  966/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  967/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  968/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  969/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  970/1000 (1 min 36 sec elapsed, 3 sec remaining)
# Iteration  971/1000 (1 min 37 sec elapsed, 3 sec remaining)
# Iteration  972/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  973/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  974/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  975/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  976/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  977/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  978/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  979/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  980/1000 (1 min 37 sec elapsed, 2 sec remaining)
# Iteration  981/1000 (1 min 38 sec elapsed, 2 sec remaining)
# Iteration  982/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  983/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  984/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  985/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  986/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  987/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  988/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  989/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  990/1000 (1 min 38 sec elapsed, 1 sec remaining)
# Iteration  991/1000 (1 min 39 sec elapsed, 1 sec remaining)
# Iteration  992/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  993/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  994/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  995/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  996/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  997/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  998/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration  999/1000 (1 min 39 sec elapsed, 0 sec remaining)
# Iteration 1000/1000 (1 min 40 sec elapsed, 0 sec remaining)
# content loss: 760289
#   style loss: 263066
#      tv loss: 44183.1
#   total loss: 1.06754e+06

# %%
import scipy
dir(scipy)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'LowLevelCallable',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_UFUNC_API',
#  '__SCIPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__numpy_version__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_add_newdoc_ufunc',
#  '_arg',
#  '_distributor_init',
#  '_lib',
#  'absolute',
#  'absolute_import',
#  'add',
#  'add_docstring',
#  'add_newdoc',
#  'add_newdoc_ufunc',
#  'alen',
#  'all',
#  'allclose',
#  'alltrue',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
#  'arctan',
#  'arctan2',
#  'arctanh',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'argwhere',
#  'around',
#  'array',
#  'array2string',
#  'array_equal',
#  'array_equiv',
#  'array_repr',
#  'array_split',
#  'array_str',
#  'asanyarray',
#  'asarray',
#  'asarray_chkfinite',
#  'ascontiguousarray',
#  'asfarray',
#  'asfortranarray',
#  'asmatrix',
#  'asscalar',
#  'atleast_1d',
#  'atleast_2d',
#  'atleast_3d',
#  'average',
#  'bartlett',
#  'base_repr',
#  'binary_repr',
#  'bincount',
#  'bitwise_and',
#  'bitwise_not',
#  'bitwise_or',
#  'bitwise_xor',
#  'blackman',
#  'block',
#  'bmat',
#  'bool8',
#  'bool_',
#  'broadcast',
#  'broadcast_arrays',
#  'broadcast_to',
#  'busday_count',
#  'busday_offset',
#  'busdaycalendar',
#  'byte',
#  'byte_bounds',
#  'bytes0',
#  'bytes_',
#  'c_',
#  'can_cast',
#  'cast',
#  'cbrt',
#  'cdouble',
#  'ceil',
#  'cfloat',
#  'char',
#  'character',
#  'chararray',
#  'choose',
#  'clip',
#  'clongdouble',
#  'clongfloat',
#  'column_stack',
#  'common_type',
#  'compare_chararrays',
#  'complex128',
#  'complex256',
#  'complex64',
#  'complex_',
#  'complexfloating',
#  'compress',
#  'concatenate',
#  'conj',
#  'conjugate',
#  'convolve',
#  'copy',
#  'copysign',
#  'copyto',
#  'corrcoef',
#  'correlate',
#  'cos',
#  'cosh',
#  'count_nonzero',
#  'cov',
#  'cross',
#  'csingle',
#  'ctypeslib',
#  'cumprod',
#  'cumproduct',
#  'cumsum',
#  'datetime64',
#  'datetime_as_string',
#  'datetime_data',
#  'deg2rad',
#  'degrees',
#  'delete',
#  'deprecate',
#  'deprecate_with_doc',
#  'diag',
#  'diag_indices',
#  'diag_indices_from',
#  'diagflat',
#  'diagonal',
#  'diff',
#  'digitize',
#  'disp',
#  'divide',
#  'division',
#  'divmod',
#  'dot',
#  'double',
#  'dsplit',
#  'dstack',
#  'dtype',
#  'e',
#  'ediff1d',
#  'einsum',
#  'einsum_path',
#  'emath',
#  'empty',
#  'empty_like',
#  'equal',
#  'errstate',
#  'euler_gamma',
#  'exp',
#  'exp2',
#  'expand_dims',
#  'expm1',
#  'extract',
#  'eye',
#  'fabs',
#  'fastCopyAndTranspose',
#  'fft',
#  'fill_diagonal',
#  'find_common_type',
#  'finfo',
#  'fix',
#  'flatiter',
#  'flatnonzero',
#  'flexible',
#  'flip',
#  'fliplr',
#  'flipud',
#  'float128',
#  'float16',
#  'float32',
#  'float64',
#  'float_',
#  'float_power',
#  'floating',
#  'floor',
#  'floor_divide',
#  'fmax',
#  'fmin',
#  'fmod',
#  'format_float_positional',
#  'format_float_scientific',
#  'format_parser',
#  'frexp',
#  'frombuffer',
#  'fromfile',
#  'fromfunction',
#  'fromiter',
#  'frompyfunc',
#  'fromregex',
#  'fromstring',
#  'full',
#  'full_like',
#  'fv',
#  'gcd',
#  'generic',
#  'genfromtxt',
#  'geomspace',
#  'get_array_wrap',
#  'get_include',
#  'get_printoptions',
#  'getbufsize',
#  'geterr',
#  'geterrcall',
#  'geterrobj',
#  'gradient',
#  'greater',
#  'greater_equal',
#  'half',
#  'hamming',
#  'hanning',
#  'heaviside',
#  'histogram',
#  'histogram2d',
#  'histogram_bin_edges',
#  'histogramdd',
#  'hsplit',
#  'hstack',
#  'hypot',
#  'i0',
#  'identity',
#  'ifft',
#  'iinfo',
#  'imag',
#  'in1d',
#  'index_exp',
#  'indices',
#  'inexact',
#  'inf',
#  'info',
#  'infty',
#  'inner',
#  'insert',
#  'int0',
#  'int16',
#  'int32',
#  'int64',
#  'int8',
#  'int_',
#  'int_asbuffer',
#  'intc',
#  'integer',
#  'interp',
#  'intersect1d',
#  'intp',
#  'invert',
#  'ipmt',
#  'irr',
#  'is_busday',
#  'isclose',
#  'iscomplex',
#  'iscomplexobj',
#  'isfinite',
#  'isfortran',
#  'isin',
#  'isinf',
#  'isnan',
#  'isnat',
#  'isneginf',
#  'isposinf',
#  'isreal',
#  'isrealobj',
#  'isscalar',
#  'issctype',
#  'issubclass_',
#  'issubdtype',
#  'issubsctype',
#  'iterable',
#  'ix_',
#  'kaiser',
#  'kron',
#  'lcm',
#  'ldexp',
#  'left_shift',
#  'less',
#  'less_equal',
#  'lexsort',
#  'linalg',
#  'linspace',
#  'little_endian',
#  'load',
#  'loads',
#  'loadtxt',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'logaddexp',
#  'logaddexp2',
#  'logical_and',
#  'logical_not',
#  'logical_or',
#  'logical_xor',
#  'logn',
#  'logspace',
#  'long',
#  'longcomplex',
#  'longdouble',
#  'longfloat',
#  'longlong',
#  'lookfor',
#  'ma',
#  'mafromtxt',
#  'mask_indices',
#  'mat',
#  'math',
#  'matmul',
#  'matrix',
#  'maximum',
#  'maximum_sctype',
#  'may_share_memory',
#  'mean',
#  'median',
#  'memmap',
#  'meshgrid',
#  'mgrid',
#  'min_scalar_type',
#  'minimum',
#  'mintypecode',
#  'mirr',
#  'mod',
#  'modf',
#  'moveaxis',
#  'msort',
#  'multiply',
#  'nan',
#  'nan_to_num',
#  'nanargmax',
#  'nanargmin',
#  'nancumprod',
#  'nancumsum',
#  'nanmax',
#  'nanmean',
#  'nanmedian',
#  'nanmin',
#  'nanpercentile',
#  'nanprod',
#  'nanquantile',
#  'nanstd',
#  'nansum',
#  'nanvar',
#  'nbytes',
#  'ndarray',
#  'ndenumerate',
#  'ndfromtxt',
#  'ndim',
#  'ndimage',
#  'ndindex',
#  'nditer',
#  'negative',
#  'nested_iters',
#  'newaxis',
#  'nextafter',
#  'nonzero',
#  'not_equal',
#  'nper',
#  'npv',
#  'number',
#  'obj2sctype',
#  'object0',
#  'object_',
#  'ogrid',
#  'ones',
#  'ones_like',
#  'outer',
#  'packbits',
#  'pad',
#  'partition',
#  'percentile',
#  'pi',
#  'piecewise',
#  'place',
#  'pmt',
#  'poly',
#  'poly1d',
#  'polyadd',
#  'polyder',
#  'polydiv',
#  'polyfit',
#  'polyint',
#  'polymul',
#  'polysub',
#  'polyval',
#  'positive',
#  'power',
#  'ppmt',
#  'print_function',
#  'printoptions',
#  'prod',
#  'product',
#  'promote_types',
#  'ptp',
#  'put',
#  'put_along_axis',
#  'putmask',
#  'pv',
#  'quantile',
#  'r_',
#  'rad2deg',
#  'radians',
#  'rand',
#  'randn',
#  'random',
#  'rank',
#  'rate',
#  'ravel',
#  'ravel_multi_index',
#  'real',
#  'real_if_close',
#  'rec',
#  'recarray',
#  'recfromcsv',
#  'recfromtxt',
#  'reciprocal',
#  'record',
#  'remainder',
#  'repeat',
#  'require',
#  'reshape',
#  'resize',
#  'result_type',
#  'right_shift',
#  'rint',
#  'roll',
#  'rollaxis',
#  'roots',
#  'rot90',
#  'round_',
#  'row_stack',
#  's_',
#  'safe_eval',
#  'save',
#  'savetxt',
#  'savez',
#  'savez_compressed',
#  'sctype2char',
#  'sctypeDict',
#  'sctypeNA',
#  'sctypes',
#  'searchsorted',
#  'select',
#  'set_numeric_ops',
#  'set_printoptions',
#  'set_string_function',
#  'setbufsize',
#  'setdiff1d',
#  'seterr',
#  'seterrcall',
#  'seterrobj',
#  'setxor1d',
#  'shape',
#  'shares_memory',
#  'short',
#  'show_config',
#  'show_numpy_config',
#  'sign',
#  'signbit',
#  'signedinteger',
#  'sin',
#  'sinc',
#  'single',
#  'singlecomplex',
#  'sinh',
#  'size',
#  'sometrue',
#  'sort',
#  'sort_complex',
#  'source',
#  'spacing',
#  'sparse',
#  'split',
#  'sqrt',
#  'square',
#  'squeeze',
#  'stack',
#  'std',
#  'str0',
#  'str_',
#  'string_',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'take',
#  'take_along_axis',
#  'tan',
#  'tanh',
#  'tensordot',
#  'test',
#  'tile',
#  'timedelta64',
#  'trace',
#  'tracemalloc_domain',
#  'transpose',
#  'trapz',
#  'tri',
#  'tril',
#  'tril_indices',
#  'tril_indices_from',
#  'trim_zeros',
#  'triu',
#  'triu_indices',
#  'triu_indices_from',
#  'true_divide',
#  'trunc',
#  'typeDict',
#  'typeNA',
#  'typecodes',
#  'typename',
#  'ubyte',
#  'ufunc',
#  'uint',
#  'uint0',
#  'uint16',
#  'uint32',
#  'uint64',
#  'uint8',
#  'uintc',
#  'uintp',
#  'ulonglong',
#  'unicode',
#  'unicode_',
#  'union1d',
#  'unique',
#  'unpackbits',
#  'unravel_index',
#  'unsignedinteger',
#  'unwrap',
#  'ushort',
#  'vander',
#  'var',
#  'vdot',
#  'vectorize',
#  'version',
#  'void',
#  'void0',
#  'vsplit',
#  'vstack',
#  'where',
#  'who',
#  'zeros',
#  'zeros_like']

# %%
# !pwd
# Out:
# /content/neural-style

# %%
# !find ./  -iname "*py" |xargs grep -ni "stylize"
# Out:
# ./stylize.py:33:def stylize(network, initial, initial_noiseblend, content, styles, preserve_colors, iterations,
# ./stylize.py:38:    Stylize images.
# ./stylize.py:94:    # make stylized image using backpropogation
# ./stylize.py:213:                        # 1. Convert stylized RGB->grayscale accoriding to Rec.601 luma (0.299, 0.587, 0.114)
# ./stylize.py:214:                        # 2. Convert stylized grayscale into YUV (YCbCr)
# ./stylize.py:216:                        # 4. Recombine (stylizedYUV.Y, originalYUV.U, originalYUV.V)
# ./neural_style.py:13:from stylize import stylize
# ./neural_style.py:216:    for iteration, image, loss_vals in stylize(
