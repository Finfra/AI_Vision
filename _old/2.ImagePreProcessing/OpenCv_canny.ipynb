# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
# !wget http://j.finfra.com/_file/messi5.jpg
# Out:
# --2020-08-02 13:10:06--  http://j.finfra.com/_file/messi5.jpg
# Resolving j.finfra.com (j.finfra.com)... 211.252.85.187
# Connecting to j.finfra.com (j.finfra.com)|211.252.85.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28602 (28K) [image/jpeg]
# Saving to: ‘messi5.jpg’
#
# messi5.jpg          100%[===================>]  27.93K   152KB/s    in 0.2s
#
# 2020-08-02 13:10:07 (152 KB/s) - ‘messi5.jpg’ saved [28602/28602]

# %%
img = cv.imread('./messi5.jpg')
plt.title('Orignal') 
plt.axis("off") 
plt.imshow(img,cmap = 'gray')

# %%
edges = cv.Canny(img,20,200)
plt.title('Canny edge detection') ;plt.axis("off") 
plt.imshow(edges,cmap = 'gray')
