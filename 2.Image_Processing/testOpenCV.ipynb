# %%
import cv2 as cv
import sys
! wget https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img/elephant.png
img = cv.imread(cv.samples.findFile("elephant.png"))

from google.colab.patches import cv2_imshow

cv2_imshow( img)

# %%
img[0,0,0]
# Out:
# 52

# %%
# !ls
# Out:
# elephant.png  elephant.png.1  elephant.png.2  sample_data

# %%
from os import listdir
import os
# dir(os)
listdir('.')
# Out:
# ['.config', 'elephant.png', 'elephant.png.1', 'elephant.png.2', 'sample_data']
