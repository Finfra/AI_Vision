# %%
# !wget https://imagemagick.org/image/wizard.jpg
# Out:
# --2020-12-01 04:04:57--  https://imagemagick.org/image/wizard.jpg
# Resolving imagemagick.org (imagemagick.org)... 44.234.227.205
# Connecting to imagemagick.org (imagemagick.org)|44.234.227.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23367 (23K) [image/jpeg]
# Saving to: ‘wizard.jpg’
#
# wizard.jpg          100%[===================>]  22.82K  --.-KB/s    in 0.1s
#
# 2020-12-01 04:04:58 (174 KB/s) - ‘wizard.jpg’ saved [23367/23367]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('wizard.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

from google.colab.patches import cv2_imshow
# cv2_imshow(img)
# cv2_imshow(dst)
cv2_imshow( cv2.hconcat((img, dst)) )
# Out:
# <PIL.Image.Image image mode=RGB size=530x352 at 0x7F5784292898>

# %%
# cf) for plt
img_=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
dst_=cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)
plt.subplot(121),plt.imshow(img_),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst_),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
