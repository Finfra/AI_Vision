# %%
# !apt install -y imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
# ...

# %%
baselink="https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img"
# !rm f.*
# !rm ele*
# Out:
# rm: cannot remove 'f.*': No such file or directory
# rm: cannot remove 'ele*': No such file or directory

# %%
# 가장 크기가 적은 포멧은?
# (logo)
filename="f"
# !wget {baselink}/{filename}.png
# !identify {filename}.png
# !convert {filename}.png {filename}.gif
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.bmp
# !ls -als
# Out:
# --2021-11-30 03:10:07--  https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img/f.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1928 (1.9K) [image/png]
# Saving to: ‘f.png’
#
# f.png               100%[===================>]   1.88K  --.-KB/s    in 0s
#
# 2021-11-30 03:10:07 (37.6 MB/s) - ‘f.png’ saved [1928/1928]
#
# f.png PNG 32x32 32x32+0+0 8-bit sRGB 1.93KB 0.000u 0:00.000
# total 36
# 4 drwxr-xr-x 1 root root 4096 Nov 30 03:10 .
# 4 drwxr-xr-x 1 root root 4096 Nov 30 03:08 ..
# 4 drwxr-xr-x 4 root root 4096 Nov 18 14:35 .config
# 8 -rw-r--r-- 1 root root 4234 Nov 30 03:10 f.bmp
# 4 -rw-r--r-- 1 root root  429 Nov 30 03:10 f.gif
# 4 -rw-r--r-- 1 root root 1279 Nov 30 03:10 f.jpg
# ...

# %%
filename="elephant"
# !wget {baselink}/{filename}.png
# !identify {filename}.png
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.gif
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.bmp
# !ls -als
# Out:
# --2021-11-30 03:10:34--  https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img/elephant.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 324995 (317K) [image/png]
# Saving to: ‘elephant.png’
#
# elephant.png        100%[===================>] 317.38K  --.-KB/s    in 0.03s
#
# 2021-11-30 03:10:35 (9.30 MB/s) - ‘elephant.png’ saved [324995/324995]
#
# elephant.png PNG 498x271 498x271+0+0 8-bit sRGB 325KB 0.000u 0:00.000
# total 1088
#   4 drwxr-xr-x 1 root root   4096 Nov 30 03:10 .
#   4 drwxr-xr-x 1 root root   4096 Nov 30 03:08 ..
#   4 drwxr-xr-x 4 root root   4096 Nov 18 14:35 .config
# 528 -rw-r--r-- 1 root root 539970 Nov 30 03:10 elephant.bmp
# 124 -rw-r--r-- 1 root root 122984 Nov 30 03:10 elephant.gif
# ...
