# %%
# !apt install -y imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# imagemagick is already the newest version (8:6.9.7.4+dfsg-16ubuntu6.8).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
baselink="https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img"
# !rm f.*
# !rm ele*
# Out:
# rm: cannot remove 'f.*': No such file or directory

# %%
# 가장 크기가 적은 포멧은?
# (logo)
filename="f"
# !wget {baselink}/{filename}.png
# !identify {filename}.png
# !convert {filename}.png {filename}.gif
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.bmp
# !ls -als
# Out:
# --2020-11-30 14:19:05--  https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img/f.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1928 (1.9K) [image/png]
# Saving to: ‘f.png’
#
# f.png               100%[===================>]   1.88K  --.-KB/s    in 0s
#
# 2020-11-30 14:19:05 (34.0 MB/s) - ‘f.png’ saved [1928/1928]
#
# f.png PNG 32x32 32x32+0+0 8-bit sRGB 1.93KB 0.000u 0:00.000
# total 36
# 4 drwxr-xr-x 1 root root 4096 Nov 30 14:19 .
# 4 drwxr-xr-x 1 root root 4096 Nov 30 12:53 ..
# 4 drwxr-xr-x 1 root root 4096 Nov 20 17:15 .config
# 8 -rw-r--r-- 1 root root 4234 Nov 30 14:19 f.bmp
# 4 -rw-r--r-- 1 root root  429 Nov 30 14:19 f.gif
# 4 -rw-r--r-- 1 root root 1279 Nov 30 14:19 f.jpg
# 4 -rw-r--r-- 1 root root 1928 Nov 30 14:19 f.png
# 4 drwxr-xr-x 1 root root 4096 Nov 13 17:33 sample_data

# %%
filename="elephant"
# !wget {baselink}/{filename}.png
# !identify {filename}.png
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.gif
# !convert {filename}.png {filename}.jpg
# !convert {filename}.png {filename}.bmp
# !ls -als
# Out:
# --2020-11-30 14:19:13--  https://raw.githubusercontent.com/Finfra/AI_Vision/master/data/img/elephant.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 315460 (308K) [image/png]
# Saving to: ‘elephant.png’
#
# elephant.png        100%[===================>] 308.07K  --.-KB/s    in 0.04s
#
# 2020-11-30 14:19:13 (7.24 MB/s) - ‘elephant.png’ saved [315460/315460]
#
# elephant.png PNG 672x480 672x480+0+0 8-bit sRGB 315KB 0.000u 0:00.000
# total 1520
#   4 drwxr-xr-x 1 root root   4096 Nov 30 14:19 .
#   4 drwxr-xr-x 1 root root   4096 Nov 30 12:53 ..
#   4 drwxr-xr-x 1 root root   4096 Nov 20 17:15 .config
# 948 -rw-r--r-- 1 root root 967818 Nov 30 14:19 elephant.bmp
# 132 -rw-r--r-- 1 root root 133529 Nov 30 14:19 elephant.gif
#  92 -rw-r--r-- 1 root root  92626 Nov 30 14:19 elephant.jpg
# 312 -rw-r--r-- 1 root root 315460 Nov 30 14:19 elephant.png
#   8 -rw-r--r-- 1 root root   4234 Nov 30 14:19 f.bmp
#   4 -rw-r--r-- 1 root root    429 Nov 30 14:19 f.gif
#   4 -rw-r--r-- 1 root root   1279 Nov 30 14:19 f.jpg
#   4 -rw-r--r-- 1 root root   1928 Nov 30 14:19 f.png
#   4 drwxr-xr-x 1 root root   4096 Nov 13 17:33 sample_data
