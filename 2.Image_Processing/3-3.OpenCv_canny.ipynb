# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
![ ! -f messi5.jpg ]&&wget http://j.finfra.com/_file/messi5.jpg

img = cv2.imread('messi5.jpg',0)
plt.title('Orignal')
plt.axis(False)
plt.imshow(img,cmap='gray')
# Out:
# --2021-11-30 04:55:18--  http://j.finfra.com/_file/messi5.jpg
# Resolving j.finfra.com (j.finfra.com)... 211.252.85.187
# Connecting to j.finfra.com (j.finfra.com)|211.252.85.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28602 (28K) [image/jpeg]
# Saving to: ‘messi5.jpg’
#
# messi5.jpg          100%[===================>]  27.93K   151KB/s    in 0.2s
#
# 2021-11-30 04:55:19 (151 KB/s) - ‘messi5.jpg’ saved [28602/28602]

# %%
edges = cv2.Canny(img,100,200)
plt.title('Orignal')
plt.axis(False)
plt.imshow(edges,cmap='gray')

# %%
# Color면? cv2_imshow(cv2.cvtColor(img2, cv2.COLOR_RGB2BGRA ))
## 현재는 gray Image라서 색깔 외곡 없이 나오는 것임.

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
