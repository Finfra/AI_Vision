# %%
# !cat /etc/*lease
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.3 LTS"
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !apt install -y imagemagick
# !convert -version
# Out:
# Version: ImageMagick 6.9.7-4 Q16 x86_64 20170114 http://www.imagemagick.org
# Copyright: © 1999-2017 ImageMagick Studio LLC
# License: http://www.imagemagick.org/script/license.php
# Features: Cipher DPC Modules OpenMP
# Delegates (built-in): bzlib djvu fftw fontconfig freetype jbig jng jpeg lcms lqr ltdl lzma openexr pangocairo png tiff wmf x xml zlib

# %%
# !wget https://www.unicef.org/sites/default/files/styles/multimedia_tablet/public/EDH4BTS.jpg
# Out:
# --2020-08-02 17:04:16--  https://www.unicef.org/sites/default/files/styles/multimedia_tablet/public/EDH4BTS.jpg
# Resolving www.unicef.org (www.unicef.org)... 23.78.92.54, 2600:1402:3800:293::23aa, 2600:1402:3800:292::23aa
# Connecting to www.unicef.org (www.unicef.org)|23.78.92.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48710 (48K) [image/jpeg]
# Saving to: ‘EDH4BTS.jpg’
#
# EDH4BTS.jpg         100%[===================>]  47.57K  --.-KB/s    in 0.03s
#
# 2020-08-02 17:04:16 (1.53 MB/s) - ‘EDH4BTS.jpg’ saved [48710/48710]

# %%
# !convert EDH4BTS.jpg EDH4BTS.png
# !convert EDH4BTS.jpg EDH4BTS.bmp
# !ls -alsh ED*
# Out:
# 792K -rw-r--r-- 1 root root 792K Aug  2 17:04 EDH4BTS.bmp
#  48K -rw-r--r-- 1 root root  48K Jan  1  1970 EDH4BTS.jpg
# 396K -rw-r--r-- 1 root root 396K Aug  2 17:04 EDH4BTS.png

# %%
# !identify EDH4BTS.png
# !identify -verbose EDH4BTS.png
# Out:
# EDH4BTS.png PNG 599x450 599x450+0+0 8-bit sRGB 405KB 0.000u 0:00.000
# Image: EDH4BTS.png
#   Format: PNG (Portable Network Graphics)
#   Mime type: image/png
#   Class: DirectClass
#   Geometry: 599x450+0+0
#   Resolution: 37.79x37.79
#   Print size: 15.8508x11.9079
#   Units: PixelsPerCentimeter
#   Type: TrueColor
#   Endianess: Undefined
#   Colorspace: sRGB
#   Depth: 8-bit
#   Channel depth:
#     red: 8-bit
#     green: 8-bit
#     blue: 8-bit
#   Channel statistics:
#     Pixels: 269550
#     Red:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 114.363 (0.448483)
#       standard deviation: 70.9714 (0.278319)
#       kurtosis: -1.0635
#       skewness: 0.100212
#       entropy: 0.989554
#     Green:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 88.7308 (0.347964)
#       standard deviation: 63.4646 (0.248881)
#       kurtosis: -1.1389
#       skewness: 0.312131
#       entropy: 0.958949
#     Blue:
#       min: 0 (0)
#       max: 255 (1)
# ...

# %%
# !identify -verbose EDH4BTS.png|grep Class
# !echo "-------------"
# !identify -verbose EDH4BTS.png|grep Class|awk '{print $2}'
# !identify -verbose EDH4BTS.png|grep Class|awk '{print $2}' > a.txt
# Out:
#   Class: DirectClass
# -------------
# DirectClass

# %%
# !wget https://imagemagick.org/image/wizard.jpg
# Out:
# --2020-08-02 17:09:53--  https://imagemagick.org/image/wizard.jpg
# Resolving imagemagick.org (imagemagick.org)... 198.72.81.86
# Connecting to imagemagick.org (imagemagick.org)|198.72.81.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23358 (23K) [image/jpeg]
# Saving to: ‘wizard.jpg.1’
#
# wizard.jpg.1        100%[===================>]  22.81K  --.-KB/s    in 0.08s
#
# 2020-08-02 17:09:54 (304 KB/s) - ‘wizard.jpg.1’ saved [23358/23358]

# %%
# !convert wizard.jpg -resize 64x64 wizard_s.jpg
# !ls -alsh wiz*
# Out:
#  24K -rw-r--r-- 1 root root  23K Mar  1  2019 wizard.jpg
# 4.0K -rw-r--r-- 1 root root 2.0K Aug  2 17:04 wizard_s.jpg

# %%
# !convert wizard.jpg -crop 40x50+100+80 wizard_c.jpg

# %%
# !ls *.jpg
# !mkdir converted
# Out:
# EDH4BTS.jpg  wizard_c.jpg  wizard.jpg  wizard_s.jpg

# %%
# %%bash
# mkdir converted
# for i in $(ls *.jpg); do
#     convert $i -resize 64x64 converted/$i
# done
# ls converted
# Out:
# EDH4BTS.jpg
# wizard_c.jpg
# wizard.jpg
# wizard_s.jpg
# mkdir: cannot create directory ‘converted’: File exists
