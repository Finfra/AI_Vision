# %%
import numpy as np
labels=['setosa','versicolor','verginica']
for i in enumerate(labels):
  print(i)
# Out:
# (0, 'setosa')
# (1, 'versicolor')
# (2, 'verginica')

# %%
ohenc=np.identity(3)
ohenc
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
ohenc[1]
# Out:
# array([0., 1., 0.])

# %%
{i:"a" for i in range(3)}
# Out:
# {0: 'a', 1: 'a', 2: 'a'}

# %%
{k:v for v,k in enumerate(labels)}
# Out:
# {'setosa': 0, 'verginica': 2, 'versicolor': 1}

# %%
enc={k:ohenc[v] for v,k in enumerate(labels)}

# %%
enc['setosa']
# Out:
# array([1., 0., 0.])

# %%
l=['setosa','versicolor','verginica','setosa','versicolor','setosa',]
ohl=[enc[i] for i in l]
ohl
# Out:
# [array([1., 0., 0.]),
#  array([0., 1., 0.]),
#  array([0., 0., 1.]),
#  array([1., 0., 0.]),
#  array([0., 1., 0.]),
#  array([1., 0., 0.])]
