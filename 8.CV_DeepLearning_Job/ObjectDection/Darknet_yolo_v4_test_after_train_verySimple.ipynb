# %%
# GPU 필수

from google.colab import drive
isMount=!df |grep /content/drive
if len(isMount)<1: drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/darknet 
# %mkdir /content/darknet
# %cd /content/darknet
# !cp /content/drive/MyDrive/Lec_Capture/_data/darknet/cfg/custom-yolov4-detector.cfg .
# !cp /content/drive/MyDrive/Lec_Capture/_data/darknet/backup/custom-yolov4-detector_last.weights .
# !cp /content/drive/MyDrive/Lec_Capture/_data/daisy/162362897_1d21b70621_m.jpg .
# !cp /content/drive/MyDrive/Lec_Capture/_data/darknet/darknet .
# Out:
# /content/darknet

# %%
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet/obj .
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet/src .
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet/include .

# %%
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet/cfg  .

# %%
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet/data .

# %%
# !./darknet detect ~.cfg ~.weights ~.png -dont-show
# !chmod +x darknet
# !./darknet detect custom-yolov4-detector.cfg custom-yolov4-detector_last.weights 162362897_1d21b70621_m.jpg -dont-show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 700, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 24, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
# ...

# %%
# !./darknet detect custom-yolov4-detector.cfg \
custom-yolov4-detector_last.weights \
/content/drive/MyDrive/Lec_Capture/_data/daisy/2632216904_274aa17433.jpg\
 -dont-show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 700, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 24, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
# ...
