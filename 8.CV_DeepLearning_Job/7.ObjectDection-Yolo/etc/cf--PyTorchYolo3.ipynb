# %% [markdown]
# # [Github Yolo V3](https://github.com/ydixon/yolo_v3)
# * link : <https://github.com/ydixon/yolo_v3>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%bash
# cd /content/drive/MyDrive
# [ ! -d ./yolo_v3 ]&&git clone https://github.com/ydixon/yolo_v3
# [ ! -f /content/drive/MyDrive/Lec_Capture/_data/yolov3.weights ]&& wget https://pjreddie.com/media/files/yolov3.weights -O /content/drive/MyDrive/yolo_v3yolov3.weights
# cp /content/drive/MyDrive/Lec_Capture/_data/yolov3.weights ./yolo_v3/weights/
# [ ! -f /content/drive/MyDrive/Lec_Capture/_data/darknet53.conv.74 ] &&wget https://pjreddie.com/media/files/darknet53.conv.74 -O /content/drive/MyDrive/darknet53.conv.74
# cp /content/drive/MyDrive/Lec_Capture/_data/darknet53.conv.74 ./yolo_v3/weights/
# ls /content/drive/MyDrive/yolo_v3/weights

# %% [markdown]
# ## COCO_ydixon
# * Download weights from https://drive.google.com/drive/folders/1HPxEA7kyJxLTu0mWYu5Vlcz57NcuD2U3?usp=sharing
#
# * 해당 폴더를 마우스 오른쪽 버튼 클릭 후 "내 드라이브에 바로 추가"클릭하면 빠르고 편하게 파일 복사 가능하지만 아래셀 실행
#
#   ```
#   %ls /content/drive/MyDrive/yolo_v3/weights/COCO_ydixon
#   ```

# %%
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/COCO_ydixon/* /content/drive/MyDrive/yolo_v3/weights/COCO_ydixon/

# %%
# %%bash
# cd /content/drive/MyDrive/yolo_v3/data
# bash get_coco_dataset.sh

# %% [markdown]
# # 실행
# * GoogleDrive에서 실행
#   - yolo_detect.ipynb
#   - yolo_train_short.ipynb
#   - yolo_train.ipynb
