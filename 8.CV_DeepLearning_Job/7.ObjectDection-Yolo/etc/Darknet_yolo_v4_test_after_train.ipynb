# %%
# %cd /content/
# %rm -rf darknet

# %%
from google.colab import drive
isMount=!df |grep /content/drive
if len(isMount)<1: drive.mount('/content/drive')

# 트레이닝 성공 후 해야할 일 → !cp -r /content/darknet /content/drive/MyDrive/

# %%
#!cp -r /content/drive/MyDrive/Lec_Capture/_data/darknet /content/
# ↑
# 너무 오래 걸리니까 아래 스크립트 실행

# %%
# !rm -rf /content/drive/MyDrive/Lec_Capture/_data/darknet/build
# !rm -rf /content/drive/MyDrive/Lec_Capture/_data/darknet/.git
# !zip -r darknet.zip /content/drive/MyDrive/Lec_Capture/_data/darknet
# !cp darknet.zip /content/drive/MyDrive/Lec_Capture/_data/
# !cp /content/drive/MyDrive/Lec_Capture/_data/darknet.zip /content/
# %cd /content
# !unzip darknet.zip
# !ls /content/drive/MyDrive/Lec_Capture/_data/|grep zip

# %%
#download the newly released yolov4 ConvNet weights
# %cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# # Set up Custom Dataset for YOLOv4

# %%
#define utility function
import os
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# !chmod +x darknet
#/test has images that we can test our detector on
test_images = [f for f in os.listdir('test') if f.endswith('.jpg')]
import random
img_path = "test/" + random.choice(test_images);

#test out our detector!
# !./darknet detect cfg/custom-yolov4-detector.cfg backup/custom-yolov4-detector_last.weights \
{img_path} -dont-show
imShow('predictions.jpg')
# Out:
# chmod: cannot access 'darknet': No such file or directory
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4bd1c0fa95f3> in <module>()
#       1 get_ipython().system('chmod +x darknet')
#       2 #/test has images that we can test our detector on
# ----> 3 test_images = [f for f in os.listdir('test') if f.endswith('.jpg')]
#       4 import random
#       5 img_path = "test/" + random.choice(test_images);
#
# NameError: name 'os' is not defined

# %%
# !ls -als backup/
# Out:
# total 1250108
#      4 drwx------  2 root root      4096 Dec 11 09:57 .
#      4 drwxr-xr-x 19 root root      4096 Dec 11 09:57 ..
# 250020 -rw-------  1 root root 256015980 Dec 11 09:57 custom-yolov4-detector_1000.weights
# 250020 -rw-------  1 root root 256015980 Dec 11 09:57 custom-yolov4-detector_2000.weights
# 250020 -rw-------  1 root root 256015980 Dec 11 09:57 custom-yolov4-detector_best.weights
# 250020 -rw-------  1 root root 256015980 Dec 11 09:57 custom-yolov4-detector_final.weights
# 250020 -rw-------  1 root root 256015980 Dec 11 09:56 custom-yolov4-detector_last.weights

# %%
# !cp -r /content/darknet/include \
/content/drive/MyDrive/Lec_Capture/_data/darknet/

# %%
# Out:
# 3rdparty			  darknet.py		 README.md
# appveyor.yml			  darknet_video.py	 README.roboflow.txt
# backup				  data			 results
# build				  image_yolov2.sh	 scripts
# build.ps1			  image_yolov3.sh	 src
# build.sh			  include		 test
# cfg				  json_mjpeg_streams.sh  train
# chart_custom-yolov4-detector.png  libdarknet.so		 uselib
# chart.png			  LICENSE		 valid
# cmake				  Makefile		 video_v2.sh
# CMakeLists.txt			  net_cam_v3.sh		 video_yolov3.sh
# darknet				  obj			 yolov4.conv.137
# DarknetConfig.cmake.in		  predictions.jpg
