# %%
# !cp -r /content/drive/MyDrive/Lec_Capture/_data/saved_model .
# !pwd
# !ls
# Out:
# /content
# drive  sample_data  saved_model

# %%
script_path=input('Input path !')
# Out:
# Input path !/content/drive/MyDrive/AI_Vision/4.CV_DeepLearning_Job/TensorflowServing

# %%
# %cd {script_path}
# !ls
# Out:
# /content/drive/MyDrive/AI_Vision/4.CV_DeepLearning_Job/TensorflowServing
# do.sh			     mlpExampleSaveModel.py
# installTensorflowServing.sh  servingRequest.py
# iris.csv		     TensorflowServingTest.ipynb
# mlpExampleCheckpoint.py

# %%
# !bash installTensorflowServing.sh

# %%
# !saved_model_cli show --dir /content/saved_model/1 --all

# %%
# !saved_model_cli run  --dir /content/saved_model/1/ \
--signature_def serving_default                      \
--tag_set=serve                                \
--input_expr "dense_input=[[1., 0., 0., 0.]]"
# Out:
# 2020-12-07 12:00:04.597415: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-07 12:00:04.650851: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-12-07 12:00:04.650911: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (645fe6d856de): /proc/driver/nvidia/version does not exist
# 2020-12-07 12:00:04.651377: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-12-07 12:00:04.678001: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000160000 Hz
# 2020-12-07 12:00:04.678262: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55572871a840 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-07 12:00:04.678301: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING: Logging before flag parsing goes to stderr.
# W1207 12:00:04.685442 140256355706752 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/tools/saved_model_cli.py:420: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# Result for output key dense_3:
# [[0.45431498 0.3280274  0.21765761]]

# %%
# %%shell
# #실행전 스크립트를 죽인다.
# pnum=$(ps -ef|grep -v gre|grep model|awk '{printf $2}')
# kill -9  $pnum
#
# # rest server실행
# tensorflow_model_server  \
# --port=9018              \
# --rest_api_port=9020     \
# --model_name=iris        \
# --model_base_path=/content/saved_model &

# %%
# !curl http://127.0.0.1:9020/v1/models/iris:predict
# Out:
# {
#     "error": "Malformed request: GET /v1/models/iris:predict"
# }

# %%
# !python3 servingRequest.py
# Out:
# [[0.05190803 0.49026781 0.45782408]]

# %%
# unbuntu용 이고요........redHat계열을 다름..
