# %%
# !apt-get install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
# ...

# %%
# %%bash
# wget http://finfra.com/f/f.png
# ls
# Out:
# f.png
# sample_data
# --2020-11-19 04:39:42--  http://finfra.com/f/f.png
# Resolving finfra.com (finfra.com)... 211.252.85.187
# Connecting to finfra.com (finfra.com)|211.252.85.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1928 (1.9K) [image/png]
# Saving to: ‘f.png’
#
#      0K .                                                     100%  146M=0s
#
# 2020-11-19 04:39:42 (146 MB/s) - ‘f.png’ saved [1928/1928]

# %%
# %%bash
# convert f.png f.jpg
# identify f.jpg
# Out:
# f.jpg JPEG 32x32 32x32+0+0 8-bit sRGB 1.28KB 0.000u 0:00.000

# %%
# !identify -verbose f.jpg
# Out:
# Image: f.jpg
#   Format: JPEG (Joint Photographic Experts Group JFIF format)
#   Mime type: image/jpeg
#   Class: DirectClass
#   Geometry: 32x32+0+0
#   Resolution: 28x28
#   Print size: 1.14286x1.14286
#   Units: PixelsPerCentimeter
#   Type: TrueColor
#   Endianess: Undefined
#   Colorspace: sRGB
#   Depth: 8-bit
#   Channel depth:
#     red: 8-bit
#     green: 8-bit
#     blue: 8-bit
#   Channel statistics:
#     Pixels: 1024
#     Red:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 48.4766 (0.190104)
#       standard deviation: 43.561 (0.170827)
#       kurtosis: -0.529562
#       skewness: 0.642036
#       entropy: 0.832583
#     Green:
#       min: 0 (0)
#       max: 184 (0.721569)
#       mean: 86.8789 (0.340702)
#       standard deviation: 59.5183 (0.233405)
#       kurtosis: -1.20669
#       skewness: -0.4363
#       entropy: 0.792194
#     Blue:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 124.369 (0.487722)
#       standard deviation: 85.1366 (0.333869)
# ...

# %%
import matplotlib.pyplot as plt
ir=plt.imread('f.png')
plt.imshow(ir)
