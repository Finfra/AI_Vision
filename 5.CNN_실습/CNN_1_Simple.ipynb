# %% [markdown]
# # Data 준비

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers

(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # 모델 설계

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='tanh', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                54090
# =================================================================
# Total params: 54,410
# Trainable params: 54,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
adam=optimizers.Adam(lr=0.003)
model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, batch_size=1000,epochs=10)
score = model.evaluate(test_images, test_labels, verbose=0)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5407 - accuracy: 0.8529
# Epoch 2/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.2337 - accuracy: 0.9345
# Epoch 3/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1718 - accuracy: 0.9518
# Epoch 4/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1325 - accuracy: 0.9633
# Epoch 5/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1074 - accuracy: 0.9699
# Epoch 6/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0909 - accuracy: 0.9749
# Epoch 7/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0790 - accuracy: 0.9783
# Epoch 8/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0701 - accuracy: 0.9802
# Epoch 9/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0640 - accuracy: 0.9819
# Epoch 10/10
# 60/60 [==============================] - 1s 10ms/step - loss: 0.0584 - accuracy: 0.9833

# %% [markdown]
# # 결과

# %%
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.07001402229070663
# Test accuracy: 0.978600025177002
