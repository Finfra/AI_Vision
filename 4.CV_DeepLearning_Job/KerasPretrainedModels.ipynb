# %%
# Confer : https://towardsdatascience.com/step-by-step-guide-to-using-pretrained-models-in-keras-c9097b647b29

# %%
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.keras import datasets, layers, models ,Input, Model

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from tensorflow.keras import datasets, layers, models, regularizers

import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
from pylab import *
from numpy import *

def getFolder(thePath,isFile=True):
    return [f for f in listdir(thePath) if isFile == isfile(join(thePath, f)) ]


def getImagesAndLabels(tPath):
    labels=getFolder(tPath,False)
    encoder={w: i for i, w in enumerate(labels)}
    decoder={i: w  for i, w in enumerate(labels)}

    
    tImages,tLabels=None,None

    for label in labels:
        imgFolder=join(tPath,label)
        files= [f for f in listdir(imgFolder) if isfile(join(imgFolder, f))]
        for file in files:
            imageFile=join(imgFolder,file)
            img=np.array([imread(imageFile)])/255.
            if tImages is None:
                tImages, tLabels =img, np.array([encoder[label]],ndmin=1)
            else:
#                 print(tImages.shape,img.shape,imageFile)
                tImages = np.vstack( (tImages,img) )
                tLabels = np.append(tLabels,np.array([encoder[label]]) ,axis=0) 
        print(label,tImages.shape)                 
    return (tImages,tLabels,encoder,decoder)

    

from sklearn.model_selection import train_test_split
basePath='../data/flower_photos_300x200_small'
imgs,labels,encoder,decoder=getImagesAndLabels(basePath)

class_cnt=len(encoder.keys())

train_images,test_images,train_labels,test_labels=train_test_split(imgs,labels,test_size=0.3333, random_state=99)


imgShape=train_images[0].shape
img_width,img_hight,color_count=imgShape
train_images = train_images.reshape((-1,img_width,img_hight,color_count ))
test_images = test_images.reshape((-1, img_width,img_hight,color_count ))

print("Shape of Train_images = ",train_images.shape)
# Out:
# daisy (100, 200, 300, 3)
# tulips (200, 200, 300, 3)
# Shape of Train_images =  (133, 200, 300, 3)

# %%
# !pwd
# Out:
# /prj/nowage/jprj/Examples

# %%
from tensorflow.python.keras.applications.vgg16 import VGG16


model=keras.models.Sequential()
model.add(VGG16(weights='imagenet'))
# model.summary()

inp=Input(shape=(224,224,3))
out=VGG16(weights='imagenet')(inp)
model=Model(inputs=inp,outputs=out)
model.summary()
# Out:
# WARNING:tensorflow:From /prj/nowage/.virtualenvs/p3t1/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Model)                (None, 1000)              138357544
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(train_labels[0])
# Out:
# 1

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=200,batch_size=10)
# Out:
# Train on 133 samples
# Epoch 1/200
# 133/133 [==============================] - 7s 52ms/sample - loss: 20.8992 - acc: 0.4812
# Epoch 2/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 24.0260 - acc: 0.6241
# Epoch 3/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.0651 - acc: 0.4812
# Epoch 4/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.9246 - acc: 0.4812
# Epoch 5/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7706 - acc: 0.4211
# Epoch 6/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7884 - acc: 0.4962
# Epoch 7/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7404 - acc: 0.4662
# Epoch 8/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7553 - acc: 0.5489
# Epoch 9/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7045 - acc: 0.4737
# Epoch 10/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7273 - acc: 0.4812
# Epoch 11/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6913 - acc: 0.5338
# Epoch 12/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7143 - acc: 0.5113
# Epoch 13/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6835 - acc: 0.5639
# Epoch 14/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6481 - acc: 0.6241
# Epoch 15/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7029 - acc: 0.5113
# Epoch 16/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7049 - acc: 0.5414
# Epoch 17/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7044 - acc: 0.4511
# Epoch 18/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7086 - acc: 0.5263
# Epoch 19/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7045 - acc: 0.5188
# Epoch 20/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7314 - acc: 0.5414
# Epoch 21/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7397 - acc: 0.5113
# Epoch 22/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7200 - acc: 0.4361
# Epoch 23/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6963 - acc: 0.5338
# Epoch 24/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7557 - acc: 0.4586
# Epoch 25/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7177 - acc: 0.3835
# Epoch 26/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7022 - acc: 0.4962
# Epoch 27/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7048 - acc: 0.5113
# Epoch 28/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7081 - acc: 0.4887
# Epoch 29/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6974 - acc: 0.4737
# Epoch 30/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7049 - acc: 0.4662
# Epoch 31/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7119 - acc: 0.4887
# Epoch 32/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7226 - acc: 0.5263
# Epoch 33/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7280 - acc: 0.4737
# Epoch 34/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7154 - acc: 0.4887
# Epoch 35/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6988 - acc: 0.5038
# Epoch 36/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7022 - acc: 0.5414
# Epoch 37/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7090 - acc: 0.5038
# Epoch 38/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7069 - acc: 0.4511
# Epoch 39/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7003 - acc: 0.3985
# Epoch 40/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7036 - acc: 0.4812
# Epoch 41/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7118 - acc: 0.4586
# Epoch 42/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7099 - acc: 0.4361
# Epoch 43/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7217 - acc: 0.4812
# Epoch 44/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6964 - acc: 0.4662
# Epoch 45/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7012 - acc: 0.4361
# Epoch 46/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6968 - acc: 0.5113
# Epoch 47/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7122 - acc: 0.4586
# Epoch 48/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7018 - acc: 0.4962
# Epoch 49/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7219 - acc: 0.4737
# Epoch 50/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7027 - acc: 0.4662
# Epoch 51/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7061 - acc: 0.4436
# Epoch 52/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6930 - acc: 0.4962
# Epoch 53/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7038 - acc: 0.5038
# Epoch 54/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7018 - acc: 0.5038
# Epoch 55/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7011 - acc: 0.4361
# Epoch 56/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6934 - acc: 0.5489
# Epoch 57/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7015 - acc: 0.4361
# Epoch 58/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6963 - acc: 0.5038
# Epoch 59/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6923 - acc: 0.5038
# Epoch 60/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7031 - acc: 0.5038
# Epoch 61/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.9929 - acc: 0.4586
# Epoch 62/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7154 - acc: 0.5789
# Epoch 63/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7390 - acc: 0.5414
# Epoch 64/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7107 - acc: 0.5489
# Epoch 65/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7233 - acc: 0.4962
# Epoch 66/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.7660 - acc: 0.4586
# Epoch 67/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.0140 - acc: 0.5113
# Epoch 68/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7018 - acc: 0.5038
# Epoch 69/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7505 - acc: 0.4887
# Epoch 70/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7068 - acc: 0.4887
# Epoch 71/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.9999 - acc: 0.4511
# Epoch 72/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 4.4793 - acc: 0.4662
# Epoch 73/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 4.3228 - acc: 0.5038
# Epoch 74/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.1424 - acc: 0.5038
# Epoch 75/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 17.5546 - acc: 0.5414
# Epoch 76/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.1387 - acc: 0.4887
# Epoch 77/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.0965 - acc: 0.5414
# Epoch 78/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 35.3480 - acc: 0.4436
# Epoch 79/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 4.5513 - acc: 0.5113
# Epoch 80/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7487 - acc: 0.5489
# Epoch 81/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7433 - acc: 0.5038
# Epoch 82/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7056 - acc: 0.4662
# Epoch 83/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7018 - acc: 0.4135
# Epoch 84/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7058 - acc: 0.5038
# Epoch 85/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6963 - acc: 0.5113
# Epoch 86/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7039 - acc: 0.4211
# Epoch 87/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6979 - acc: 0.4962
# Epoch 88/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6936 - acc: 0.4962
# Epoch 89/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.4662
# Epoch 90/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6944 - acc: 0.5038
# Epoch 91/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6955 - acc: 0.4286
# Epoch 92/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6935 - acc: 0.5038
# Epoch 93/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6936 - acc: 0.5038
# Epoch 94/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6935 - acc: 0.4737
# Epoch 95/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6943 - acc: 0.4962
# Epoch 96/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.4511
# Epoch 97/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6964 - acc: 0.4586
# Epoch 98/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.5038
# Epoch 99/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6952 - acc: 0.4211
# Epoch 100/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6943 - acc: 0.4662
# Epoch 101/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.4586
# Epoch 102/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6951 - acc: 0.5038
# Epoch 103/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6960 - acc: 0.5038
# Epoch 104/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6968 - acc: 0.4361
# Epoch 105/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6934 - acc: 0.5038
# Epoch 106/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6963 - acc: 0.4962
# Epoch 107/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6992 - acc: 0.4436
# Epoch 108/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7151 - acc: 0.4662
# Epoch 109/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6988 - acc: 0.4962
# Epoch 110/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6964 - acc: 0.4511
# Epoch 111/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6926 - acc: 0.5188
# Epoch 112/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6940 - acc: 0.4812
# Epoch 113/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6940 - acc: 0.5188
# Epoch 114/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6918 - acc: 0.5414
# Epoch 115/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7028 - acc: 0.4586
# Epoch 116/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7008 - acc: 0.5038
# Epoch 117/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6969 - acc: 0.5038
# Epoch 118/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.5038
# Epoch 119/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6956 - acc: 0.4812
# Epoch 120/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6955 - acc: 0.4962
# Epoch 121/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6934 - acc: 0.4962
# Epoch 122/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6947 - acc: 0.3835
# Epoch 123/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6936 - acc: 0.5038
# Epoch 124/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.5038
# Epoch 125/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.4211
# Epoch 126/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6953 - acc: 0.4436
# Epoch 127/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6940 - acc: 0.5038
# Epoch 128/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6950 - acc: 0.4361
# Epoch 129/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6963 - acc: 0.5038
# Epoch 130/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6948 - acc: 0.5038
# Epoch 131/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6940 - acc: 0.5188
# Epoch 132/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6957 - acc: 0.4737
# Epoch 133/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6948 - acc: 0.4662
# Epoch 134/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6954 - acc: 0.4812
# Epoch 135/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6926 - acc: 0.5338
# Epoch 136/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7019 - acc: 0.4737
# Epoch 137/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7024 - acc: 0.5338
# Epoch 138/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.2983 - acc: 0.5038
# Epoch 139/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6957 - acc: 0.5414
# Epoch 140/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7032 - acc: 0.4211
# Epoch 141/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6941 - acc: 0.4812
# Epoch 142/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7303 - acc: 0.5714
# Epoch 143/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7011 - acc: 0.4511
# Epoch 144/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7175 - acc: 0.4812
# Epoch 145/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7015 - acc: 0.4586
# Epoch 146/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7006 - acc: 0.4662
# Epoch 147/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6927 - acc: 0.4887
# Epoch 148/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6841 - acc: 0.5639
# Epoch 149/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6959 - acc: 0.6090
# Epoch 150/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6778 - acc: 0.5113
# Epoch 151/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6735 - acc: 0.5714
# Epoch 152/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7485 - acc: 0.6767
# Epoch 153/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6812 - acc: 0.5414
# Epoch 154/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6539 - acc: 0.5940
# Epoch 155/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6771 - acc: 0.5489
# Epoch 156/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 1.1047 - acc: 0.5113
# Epoch 157/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6442 - acc: 0.6090
# Epoch 158/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.5945 - acc: 0.6992
# Epoch 159/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6180 - acc: 0.6316
# Epoch 160/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6023 - acc: 0.6391
# Epoch 161/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.5309 - acc: 0.7143
# Epoch 162/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.5330 - acc: 0.7594
# Epoch 163/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6502 - acc: 0.6241
# Epoch 164/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.5986 - acc: 0.6842
# Epoch 165/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.5272 - acc: 0.6692
# Epoch 166/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7978 - acc: 0.5564
# Epoch 167/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7342 - acc: 0.4436
# Epoch 168/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7888 - acc: 0.4286
# Epoch 169/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.7035 - acc: 0.5038
# Epoch 170/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6960 - acc: 0.4962
# Epoch 171/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.4887
# Epoch 172/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6956 - acc: 0.5038
# Epoch 173/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6953 - acc: 0.5038
# Epoch 174/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6950 - acc: 0.5038
# Epoch 175/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6978 - acc: 0.5038
# Epoch 176/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6970 - acc: 0.5038
# Epoch 177/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6951 - acc: 0.5038
# Epoch 178/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.5038
# Epoch 179/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6936 - acc: 0.5038
# Epoch 180/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6942 - acc: 0.5038
# Epoch 181/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6946 - acc: 0.5038
# Epoch 182/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6937 - acc: 0.5038
# Epoch 183/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6937 - acc: 0.4887
# Epoch 184/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6952 - acc: 0.4286
# Epoch 185/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6949 - acc: 0.4135
# Epoch 186/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6943 - acc: 0.5113
# Epoch 187/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6947 - acc: 0.3835
# Epoch 188/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6942 - acc: 0.4812
# Epoch 189/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.4361
# Epoch 190/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.4586
# Epoch 191/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6935 - acc: 0.5038
# Epoch 192/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6956 - acc: 0.5038
# Epoch 193/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6952 - acc: 0.5038
# Epoch 194/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6938 - acc: 0.5038
# Epoch 195/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6936 - acc: 0.5038
# Epoch 196/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6944 - acc: 0.4812
# Epoch 197/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6937 - acc: 0.5038
# Epoch 198/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6942 - acc: 0.5038
# Epoch 199/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6945 - acc: 0.4511
# Epoch 200/200
# 133/133 [==============================] - 3s 25ms/sample - loss: 0.6939 - acc: 0.4286

# %%
score = model.evaluate(test_images, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.6934624252034657
# Test accuracy: 0.4477612
