# %%
# %%bash
# echo "
# from flask import Flask
# app = Flask(__name__)
#
# @app.route('/')
# def hello_world():
#     return 'Hello World!'
#
# if __name__ == '__main__':
#     app.run()
# " > app.py

# %%
# !ls
# Out:
# app.py	sample_data

# %%
# !python app.py
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://0714f0e81da1.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [21/Dec/2020 09:48:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Dec/2020 09:48:21] "GET /favicon.ico HTTP/1.1" 404 -
# ^C

# %%
# !curl http://127.0.0.1:5000/
# Out:
# curl: (7) Failed to connect to 127.0.0.1 port 5000: Connection refused

# %%
# !ps -ef|grep python
# Out:
# root          50       1  0 09:47 ?        00:00:01 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --LargeFileManager.delete_to_trash=False --MappingKernelManager.root_dir="/content"
# root          57      50  1 09:47 ?        00:00:02 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-e03acd84-a2a4-4ac5-aad5-6f421592401d.json
# root         121      57  0 09:50 ?        00:00:00 /bin/bash -c ps -ef|grep python
# root         123     121  0 09:50 ?        00:00:00 grep python

# %%
# !kill -9 103
# Out:
# /bin/bash: line 0: kill: (103) - No such process
