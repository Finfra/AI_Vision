# %% [markdown]
# # Building Autoencoders in Keras
# * Source : https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# ![-](https://blog.keras.io/img/ae/autoencoder_schema.jpg)
#
# ## 자기 자신을 학습한다.
# 즉, 입력데이터와 레이블이 같다.

# %% [markdown]
# 아래에 결과가 있습니다. 위의 줄은 원래의 숫자이고 아랫 줄은 재구성된 숫자입니다. 지금 사용한 간단한 접근 방법으로 꽤 많은 비트 손실이 있었다는 것을 알 수 있습니다.
#
#
#
# Adding a sparsity constraint on the encoded representations
#
# 이전 예제에서, 표현(representation)은 은닉층의 크기(32)에만 제약을 받았습니다. 이러한 상황에서, 전형적으로 발생하는 일은 은닉층이 PCA(principal component analysis)의 근사값을 학습한다는 것입니다. 표현을 더 간결하게 제한하는 다른 방법은 숨겨진 표현의 활동에 sparsity를 부여하는 것입니다. 이는 주어진 시간에 더 적은 유닛이 “실행”될 수 있도록 합니다. Keras에서는 activity_regularizer를 Dense layer에 추가하여 수행할 수 있습니다.

# %%
# %matplotlib notebook
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers

# %%
# this is our input placeholder
x = Input(shape=(784,))
# "encoded" is the encoded representation of the input
x1 = Dense(400, activation='relu')(x)
z = Dense(32, activation='relu')(x1)
# "decoded" is the lossy reconstruction of the input
y1 = Dense(256, activation='relu')(z)
y = Dense(784, activation='sigmoid')(y1)



# this model maps an input to its reconstruction
autoencoder = Model(x, y)

# %%
# this model maps an input to its encoded representation
encoder = Model(x, z)


# create a placeholder for an encoded (32-dimensional) input
z = Input(shape=(32,))
# retrieve the last layer of the autoencoder model
y1 = autoencoder.layers[-2](z)
y  = autoencoder.layers[-1](y1)
# create the decoder model
decoder = Model(z, y)

# %%
opt=optimizers.RMSprop(lr=0.02, rho=0.9, epsilon=None, decay=0.0)
autoencoder.compile(optimizer=opt, loss='binary_crossentropy',metrics=['accuracy'],)

# %%
from tensorflow.python.keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)
print( x_train.shape)
print( x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),verbose=2)
# Out:
# Epoch 1/50
# 235/235 - 1s - loss: 0.3676 - accuracy: 0.0110 - val_loss: 0.1766 - val_accuracy: 0.0087
# Epoch 2/50
# 235/235 - 1s - loss: 0.1596 - accuracy: 0.0110 - val_loss: 0.1625 - val_accuracy: 0.0099
# Epoch 3/50
# 235/235 - 1s - loss: 0.1536 - accuracy: 0.0113 - val_loss: 0.1575 - val_accuracy: 0.0092
# Epoch 4/50
# 235/235 - 1s - loss: 0.1509 - accuracy: 0.0110 - val_loss: 0.1487 - val_accuracy: 0.0100
# Epoch 5/50
# 235/235 - 1s - loss: 0.1494 - accuracy: 0.0117 - val_loss: 0.1520 - val_accuracy: 0.0118
# Epoch 6/50
# 235/235 - 1s - loss: 0.1485 - accuracy: 0.0118 - val_loss: 0.1502 - val_accuracy: 0.0132
# Epoch 7/50
# 235/235 - 1s - loss: 0.1477 - accuracy: 0.0120 - val_loss: 0.1561 - val_accuracy: 0.0131
# Epoch 8/50
# 235/235 - 1s - loss: 0.1471 - accuracy: 0.0116 - val_loss: 0.1497 - val_accuracy: 0.0107
# Epoch 9/50
# 235/235 - 1s - loss: 0.1465 - accuracy: 0.0118 - val_loss: 0.1523 - val_accuracy: 0.0108
# Epoch 10/50
# 235/235 - 1s - loss: 0.1463 - accuracy: 0.0114 - val_loss: 0.1440 - val_accuracy: 0.0137
# Epoch 11/50
# 235/235 - 1s - loss: 0.1456 - accuracy: 0.0119 - val_loss: 0.1505 - val_accuracy: 0.0108
# Epoch 12/50
# 235/235 - 1s - loss: 0.1454 - accuracy: 0.0127 - val_loss: 0.1498 - val_accuracy: 0.0136
# Epoch 13/50
# 235/235 - 1s - loss: 0.1451 - accuracy: 0.0136 - val_loss: 0.1472 - val_accuracy: 0.0104
# Epoch 14/50
# 235/235 - 1s - loss: 0.1448 - accuracy: 0.0126 - val_loss: 0.1482 - val_accuracy: 0.0157
# Epoch 15/50
# 235/235 - 1s - loss: 0.1444 - accuracy: 0.0122 - val_loss: 0.1488 - val_accuracy: 0.0111
# Epoch 16/50
# 235/235 - 1s - loss: 0.1444 - accuracy: 0.0121 - val_loss: 0.1512 - val_accuracy: 0.0106
# Epoch 17/50
# 235/235 - 1s - loss: 0.1441 - accuracy: 0.0132 - val_loss: 0.1483 - val_accuracy: 0.0122
# Epoch 18/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0121 - val_loss: 0.1553 - val_accuracy: 0.0149
# Epoch 19/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0125 - val_loss: 0.1525 - val_accuracy: 0.0105
# Epoch 20/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0124 - val_loss: 0.1475 - val_accuracy: 0.0103
# Epoch 21/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0124 - val_loss: 0.1434 - val_accuracy: 0.0137
# Epoch 22/50
# 235/235 - 1s - loss: 0.1435 - accuracy: 0.0121 - val_loss: 0.1459 - val_accuracy: 0.0118
# Epoch 23/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0115 - val_loss: 0.1441 - val_accuracy: 0.0102
# Epoch 24/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0125 - val_loss: 0.1442 - val_accuracy: 0.0111
# Epoch 25/50
# 235/235 - 1s - loss: 0.1436 - accuracy: 0.0126 - val_loss: 0.1490 - val_accuracy: 0.0098
# Epoch 26/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0119 - val_loss: 0.1436 - val_accuracy: 0.0144
# Epoch 27/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0119 - val_loss: 0.1441 - val_accuracy: 0.0121
# Epoch 28/50
# 235/235 - 1s - loss: 0.1434 - accuracy: 0.0121 - val_loss: 0.1460 - val_accuracy: 0.0145
# Epoch 29/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0125 - val_loss: 0.1445 - val_accuracy: 0.0124
# Epoch 30/50
# 235/235 - 1s - loss: 0.1436 - accuracy: 0.0117 - val_loss: 0.1488 - val_accuracy: 0.0115
# Epoch 31/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0117 - val_loss: 0.1514 - val_accuracy: 0.0131
# Epoch 32/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0120 - val_loss: 0.1424 - val_accuracy: 0.0138
# Epoch 33/50
# 235/235 - 1s - loss: 0.1435 - accuracy: 0.0118 - val_loss: 0.1431 - val_accuracy: 0.0143
# Epoch 34/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0121 - val_loss: 0.1448 - val_accuracy: 0.0129
# Epoch 35/50
# 235/235 - 1s - loss: 0.1437 - accuracy: 0.0123 - val_loss: 0.1428 - val_accuracy: 0.0106
# Epoch 36/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0124 - val_loss: 0.1464 - val_accuracy: 0.0154
# Epoch 37/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0124 - val_loss: 0.1435 - val_accuracy: 0.0118
# Epoch 38/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0120 - val_loss: 0.1451 - val_accuracy: 0.0123
# Epoch 39/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0117 - val_loss: 0.1429 - val_accuracy: 0.0149
# Epoch 40/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0120 - val_loss: 0.1531 - val_accuracy: 0.0118
# Epoch 41/50
# 235/235 - 1s - loss: 0.1440 - accuracy: 0.0125 - val_loss: 0.1428 - val_accuracy: 0.0100
# Epoch 42/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0121 - val_loss: 0.1437 - val_accuracy: 0.0164
# Epoch 43/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0127 - val_loss: 0.1450 - val_accuracy: 0.0118
# Epoch 44/50
# 235/235 - 1s - loss: 0.1440 - accuracy: 0.0123 - val_loss: 0.1429 - val_accuracy: 0.0127
# Epoch 45/50
# 235/235 - 1s - loss: 0.1440 - accuracy: 0.0130 - val_loss: 0.1563 - val_accuracy: 0.0136
# Epoch 46/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0130 - val_loss: 0.1445 - val_accuracy: 0.0107
# Epoch 47/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0128 - val_loss: 0.1516 - val_accuracy: 0.0080
# Epoch 48/50
# 235/235 - 1s - loss: 0.1440 - accuracy: 0.0119 - val_loss: 0.1496 - val_accuracy: 0.0108
# Epoch 49/50
# 235/235 - 1s - loss: 0.1439 - accuracy: 0.0122 - val_loss: 0.1478 - val_accuracy: 0.0145
# Epoch 50/50
# 235/235 - 1s - loss: 0.1438 - accuracy: 0.0121 - val_loss: 0.1474 - val_accuracy: 0.0109

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 

# encode and decode some digits
# note that we take them from the *test* set
z = encoder.predict(x_test,  batch_size=10)
y = decoder.predict(z)


# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(y[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
